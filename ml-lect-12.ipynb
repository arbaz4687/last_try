# %% [markdown]
# ### What is Decission Tree Classifier(Theory)
# A decision Tree classifier working in a a heirarical manners .I mean in which we are represented all the data into parents and child relationship.it is provide us the informayion on the base of if_else_staemnent.It is a greedy algorithm means its always select the maximum value of child and not care about maybe maximum profit child provide low value at the next node .
# A top node (circle) is called a Root node and last node that is our leaf node tht is provide the final results . There is two things import in tree
# - Entropy
# - Gini index
#
#    both are used for determinewhich nodes have how many information,Mostly a top node have a maximum information and last leaf have a small information.

# %% [markdown]
# #### practicle work ..

# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
df=sns.load_dataset("iris")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
X=df[["sepal_length","sepal_width","petal_length","petal_width"]]
y=df["species"]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %%
### plotin of decsion tree 
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
model=DecisionTreeClassifier().fit(X,y)
plot_tree(model,filled=True)
plt.title("Tree_plot")
plt.show()
